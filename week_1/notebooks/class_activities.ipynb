# %% [markdown]
# ## Numerical Summary

# %%
import pandas as pd
import numpy as np
import seaborn as sns


data = np.array((5.9, 7.2, 7.3, 6.3, 8.1, 6.8, 7, 7.6, 6.8, 6.5, 7, 6.3, 7.9, 9,
        8.2, 8.7, 7.8, 9.7, 7.4, 7.7, 9.7, 7.8, 7.7, 11.6, 11.3, 11.8, 10.7))

df = pd.DataFrame(data)
df_stats = df.describe()

print(f'Min: {df_stats.loc["min"][0]}')
print(f'1st Qu: {df_stats.loc["25%"][0]}')
print(f'Median: {df.median()[0]}')
print(f'Mean: {df_stats.loc["mean"][0]}')
print(f'3rd Qu: {df_stats.loc["75%"][0]}')
print(f'Max: {df_stats.loc["max"][0]}')
print(f'STD: {df_stats.loc["std"][0]}')
print(f'VAR: {df.var()[0]}')
print(f'IQR: {df_stats.loc["75%"][0] - df_stats.loc["25%"][0]}')
# Out:
# Min: 5.9
# 1st Qu: 7.0
# Median: 7.7
# Mean: 8.14074074074074
# 3rd Qu: 8.85
# Max: 11.8
# STD: 1.659531736377941
# VAR: 2.754045584045584
# IQR: 1.8499999999999996

# %% [markdown]
# ## Graphical Summary

# %%
df_2 = pd.DataFrame({'age' : (33,32,32,28,29,29,29,33,31,32)})
df_2.plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# ### Sodium

# %% [markdown]
# #### Histogram

# %%
df3 = pd.read_csv("..\lecture_resources\Lec1_exp121_sodiumcereal.csv")
sns.histplot(data= df3)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.histplot(data=df3, x='Sodium', hue='Cereal', multiple='layer')
# Out:
# <AxesSubplot: xlabel='Sodium', ylabel='Count'>

# %% [markdown]
# #### Box Plot

# %%
# OUTLIERS
df3_stats = df3.describe()
IQR = df3_stats.loc['75%'] - df3_stats.loc['25%']
df3['Outlier'] = df3.Sodium.apply(lambda x : ((x - df3_stats.loc['25%'] - 1.5 * IQR < 0) ^ (x + df3_stats.loc['75%'] + 1.5 * IQR > 0))).Sodium
df3[df3['Outlier'] == True]
# Out:
#     Sodium Cereal  Outlier
# 1      408      G     True
# 4      359      G     True
# 20     362      K     True

# %%
df3.columns
# Out:
# Index(['Sodium', 'Cereal', 'Outlier'], dtype='object')

# %%
sns.boxplot(data=df3[['Sodium', 'Cereal']], y= 'Sodium', x='Cereal')
# Out:
# <AxesSubplot: xlabel='Cereal', ylabel='Sodium'>

# %% [markdown]
# ### OSA

# %%
df4 = pd.read_csv("..\lecture_resources\Lec1_exp1201_widthbyOSA.csv", index_col='i')
df4.head(3)
# Out:
#    Width   OSA
# i
# 1   0.40  1.02
# 2   0.42  1.21
# 3   0.48  0.88

# %%
sns.scatterplot(data=df4, x='Width', y='OSA')
# Out:
# <AxesSubplot: xlabel='Width', ylabel='OSA'>

# %% [markdown]
# ### Time Series Plot

# %%
df5 = pd.DataFrame(
    {
        'Month': range(1, 13),
        'HbA1c' : [5.2, 5.8, 5.9, 5.9, 5.5, 5.6, 5.3, 5.2, 5.3, 5.4, 5.5, 5.6]
    }
)

import matplotlib 
sns.lineplot(data=df5, x='Month', y='HbA1c', marker='o')
# Out:
# <AxesSubplot: xlabel='Month', ylabel='HbA1c'>
