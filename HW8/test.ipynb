# %%
from scipy.stats import norm

# %%
df_test = pd.read_csv('Extensibility.csv')
df_test.head()
# Out:
#    Extensibility_H  Extensibility_P
# 0             1.20             1.85
# 1             0.90             1.50
# 2             0.70             1.25
# 3             1.05             2.15
# 4             1.70             1.75

# %%
df_test["Normalized_Extensibility_H"] = (df_test.Extensibility_H - df_test.Extensibility_H.mean())/df_test.Extensibility_H.std()
df_test.head()
# Out:
#    Extensibility_H  Extensibility_P  Normalized_Extensibility_H
# 0             1.20             1.85                   -0.692696
# 1             0.90             1.50                   -1.448364
# 2             0.70             1.25                   -1.952143
# 3             1.05             2.15                   -1.070530
# 4             1.70             1.75                    0.566751

# %%
import numpy as np
df_test.sort_values(by='Normalized_Extensibility_H', inplace=True)
theoratical = np.sort(np.random.normal(size=df_test.Normalized_Extensibility_H.size))
df_test['Theoratical_Extensibility_H'] = theoratical
df_test.plot(kind='kde', y=["Normalized_Extensibility_H", "Theoratical_Extensibility_H"])
# Out:
# <AxesSubplot:ylabel='Density'>
